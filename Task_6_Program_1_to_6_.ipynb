# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddaraj777/Task-6-/blob/main/Task_6_Program_1_to_6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def smart_parking(capacity, vehicle_logs):
    current_count = 0

    for log in vehicle_logs:
        if log == "IN":
            current_count += 1
        elif log == "OUT":
            current_count -= 1

    print("Currently Parked Vehicles:", current_count)

    if current_count > capacity:
        print("Parking Status: Full – Alert!")
    else:
        print("Parking Status: Available")


# Sample Input
capacity = 50
vehicle_logs = ["IN", "IN", "IN", "OUT", "IN", "IN", "OUT"]

# Function Call
smart_parking(capacity, vehicle_logs)
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available

# %%
def estimate_delivery_time(distance, traffic, weather):
    # Base delivery time
    time = distance * 5

    # Traffic delay
    if traffic == "High":
        time += 10
    elif traffic == "Medium":
        time += 5

    # Weather delay
    if weather == "Rainy":
        time += 5

    print("Estimated Delivery Time:", time, "minutes")


# Sample Input
distance = 8
traffic = "High"
weather = "Rainy"

# Function Call
estimate_delivery_time(distance, traffic, weather)
# Out:
# Estimated Delivery Time: 55 minutes

# %%
def seat_occupancy_analyzer(total_seats, booked_seats):
    booked_count = len(booked_seats)
    occupancy = (booked_count / total_seats) * 100

    print("Occupancy:", int(occupancy), "%")

    if occupancy == 100:
        print("Show Status: Housefull")
    elif occupancy >= 70:
        print("Show Status: Almost Full")
    else:
        print("Show Status: Seats Available")


# Sample Input
total_seats = 200
booked_seats = [1] * 150   # 150 booked seats

# Function Call
seat_occupancy_analyzer(total_seats, booked_seats)
# Out:
# Occupancy: 75 %
# Show Status: Almost Full

# %%
def classify_server_load(cpu_readings):
    total = 0

    for reading in cpu_readings:
        total += reading

    average = total / len(cpu_readings)

    print("Average CPU Load:", int(average), "%")

    if average < 50:
        print("Server Status: Normal")
    elif average < 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")


# Sample Input
cpu_readings = [45, 60, 70, 85, 90]

# Function Call
classify_server_load(cpu_readings)
# Out:
# Average CPU Load: 70 %
# Server Status: Warning

# %%
def monitor_resource_usage(resource_usage):
    limit = 8
    overused = []

    for resource, hours in resource_usage.items():
        if hours > limit:
            overused.append(resource)

    if overused:
        print("Overused Resources:", ", ".join(overused))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")


# Sample Input
resource_usage = {
    "Projector": 6,
    "AC": 9,
    "Lights": 4
}

# Function Call
monitor_resource_usage(resource_usage)
# Out:
# Overused Resources: AC
# Energy Alert: Yes

# %%
def event_registration_controller(capacity, registrations):
    confirmed = 0
    waitlisted = 0

    for i in range(registrations):
        if confirmed < capacity:
            confirmed += 1
        else:
            waitlisted += 1

    print("Confirmed Registrations:", confirmed)
    print("Waitlisted Users:", waitlisted)

    if confirmed == capacity:
        print("Registration Status: Closed")
    else:
        print("Registration Status: Open")


# Sample Input
capacity = 100
registrations = 105

# Function Call
event_registration_controller(capacity, registrations)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
